# %%
import rpyc
from rpyc.utils.server import Server, ThreadedServer
from rpyc import async_
from threading import Thread, Lock, RLock
import time
import copy


mt = RLock()

class Myservice(rpyc.Service):
    def __init__(self):
        self.ls_child = ls_child
        self.child_conn = []
        self.bgthreads = []
        self.func = None
        self.id_list = []
        self.async_objs = []
        self.l = []
        self.shadow = None
        self.gran = 5
        self.lc = 0
        self.id = 21
        self.counter = 1
        self.finishes = {}
        self.pkt_details = {}
        self.is_shadow = False
        
        for ch in self.ls_child:
            c = rpyc.connect(ch[0], ch[1])
            self.child_conn.append(c)
            self.bgthreads.append(rpyc.BgServingThread(c))
#             self.on_connect(c)
        if(self.is_shadow):
            self.sent_packets = []
        else:
            self.shadow = shadow
            self.shadow_conn = rpyc.connect(self.shadow[0], self.shadow[1])
            self.shadow_bg = rpyc.BgServingThread(self.shadow_conn)
    
            
    def on_finish(self):

        if(len(self.finishes) == (len(self.child_conn) + 1)):
            print("enter")
            print(self.lc)
            while(len(self.l) > self.lc):
                send = self.gran
                if (len(self.l) - self.lc < self.gran):
                    send = len(self.l) - self.lc
                self.pkt_details[str(self.counter)] = (self.lc, send)
                self.func(self.counter, self.l[self.lc:self.lc+send], self.id, self.ack_func)
                self.counter += 1
                print("on_finish waala {}".format(self.counter))
                self.lc += send
    
    def exposed_packet_ack(self, l):
        self.sent_packets.extend(l)
        print(l)
        
    def exposed_print_pkt_list(self):
        print(self.sent_packets)
    
    def ack_func(self, ID):
        print("Ack recieved for packet id {}".format(ID))
        vals = self.pkt_details[str(ID)]
        self.shadow_conn.root.packet_ack(self.id_list[vals[0]:vals[0]+vals[1]])
    
    
    def cback(self, pkt_id, value, ID, ack_func, fin = False):
        global mt
#         print("Before acquiring by " + str(ID))
        #print(mt.locked())
        mt.acquire()
        try:
            if(fin == True):
                print("fin called by{}".format(ID))
                self.finishes[str(ID)] = True
                self.on_finish()
            else:                
# #                 print("in cback " + str(ID))
                idl = []
                
                for _ in range(len(value)):
                    idl.append(ID)

                self.id_list.extend(idl)
        #         print(value)
                #print(mt.locked())
                
#                 print(len(value))
                self.l.extend(value)
#                 print(pkt_id, ID, self.id)
                if (ID != self.id):
                    ack_func(pkt_id)
#                 print("lala")
#                 print("Value written")
#                 print (len(self.l))

                while(len(self.l) - self.lc >= self.gran):
    #                 print('andar {}'.format(ID))
                    self.pkt_details[str(self.counter)] = (self.lc, self.gran)
                    self.func(self.counter, self.l[self.lc:self.lc+self.gran], self.id, self.ack_func)
#                     print(str(self.counter), self.pkt_details[str(self.counter)])
                    self.counter += 1
                    print("cback waala {}".format(self.counter))
                    self.lc += self.gran
                    
#                 print(len(self.l) - self.lc)
#             print('in cback print {}'.format(ID))
#             print(self.l)
#             print("pople")
            
        except Exception as e:
            print(e)
        finally:
            mt.release()
#             print("mutex released")
        
        return
    
    def on_connect(self, conn):
        print("Connection established with "+ str(conn))
        
    def on_disconnect(self,conn):
        print("Have a nice day... goodbye")
        
    def exposed_printvals(self):
        print(self.l)
        print(self.id_list)
    
    def local_search(self):
        fn = self.cback
        for j in range(10):
            l = []
            for i in range(200 + 10*j,200 + 10*j + 10):
                l.append(i)


            time.sleep(1)
            print("done " + str(j))
            fn(j, l, self.id, self.ack_func)
            print("sent " + str(j))
        
        fn(None, None, self.id, None, True)   
            
    def exposed_do_a_search(self, func):
        global mt
        
        self.func = func
#         for child in self.child_conn:
#             ID = child.root.get_id()
#             self.mapper[str(ID)] = child
            
        for child in self.child_conn:
            asearch = async_(child.root.do_a_search)
            aobj = asearch(self.cback)
            self.async_objs.append(aobj)

        
        self.local_search()
#         if(self.is_shadow == False):
#             self.shadow_conn.root.print_pkt_list()
        
#         while True:
#             time.sleep(2)
#             mt.acquire()
#             try:
#                 flag = 1
#                 for _, value in self.finishes.items():
#                     if(value == False):
#                         flag = 0
#                         break
#                 if(flag == 1):
# #                     while(len(self.l) > self.lc):
# #                         send = self.gran
# #                         if (len(self.l) - self.lc < self.gran):
#                         send = len(self.l) - self.lc
#                         self.func(self.l[self.lc:self.lc+send], self.id_list[self.lc:self.lc+send])
#                         self.counter += 1
#                         print(self.counter)
#                         self.lc += send
                        
#             finally:
#                 mt.release()
        
#         while True:
#             time.sleep(1)
# #             print("lolol")
#             print("Before acquiring - while")
#             #print(mt.locked())
#             mt.acquire()
#             try:
#                 print("in while")
#                 #print(mt.locked())
#                 if(len(self.l)>=2 and times <=10):
#                     print("1")
#                     times += 1
#     #                 id1 = copy.deepcopy(self.id_list)
#     #                 print(id1)
#                     print("Sending pac")
# #                     print("in while print " +  str(times) + " " + str(self.l) )
#     #                 l1 = copy.deepcopy(self.l)
#                     print("blah")
#                     func(self.l[lc:lc+2], self.id_list[lc:lc+2])
#                     lc += 2
#             except Exception as e:
#                 print(e)
#             finally:
#                 mt.release()
#             if(times > 10):
#                 break
#             print("while mutex released")

# %%
ls_child = []
ls_child.append(("localhost", 18850, 11))
ls_child.append(("localhost", 18851, 12))

shadow = ["localhost", 17752]

# %%
t = ThreadedServer(Myservice, port = 18852)
t.start()
# Out:
# Connection established with <rpyc.core.protocol.Connection 'conn56' object at 0x7f5ad44c1b70>
# done 0
# 10
# 0 21 21
# lala
# Ack recieved for packet id 1
# 1 (0, 5)
# cback waala 2
# Ack recieved for packet id 2
# 2 (5, 5)
# cback waala 3
# 0
# sent 0
# 10
# 0 11 21
# lala
# Ack recieved for packet id 3
# 3 (10, 5)
# cback waala 4
# Ack recieved for packet id 4
# 4 (15, 5)
# cback waala 5
# 0
# 10
# 0 12 21
# lala
# Ack recieved for packet id 5
# 5 (20, 5)
# cback waala 6
# Ack recieved for packet id 6
# 6 (25, 5)
# cback waala 7
# 0
# done 1
# 10
# 1 21 21
# lala
# Ack recieved for packet id 7
# 7 (30, 5)
# cback waala 8
# Ack recieved for packet id 8
# 8 (35, 5)
# cback waala 9
# 0
# sent 1
# 10
# 1 11 21
# lala
# Ack recieved for packet id 9
# 9 (40, 5)
# cback waala 10
# Ack recieved for packet id 10
# 10 (45, 5)
# cback waala 11
# 0
# 10
# 1 12 21
# lala
# Ack recieved for packet id 11
# 11 (50, 5)
# cback waala 12
# Ack recieved for packet id 12
# 12 (55, 5)
# cback waala 13
# 0
# done 2
# 10
# 2 21 21
# lala
# Ack recieved for packet id 13
# 13 (60, 5)
# cback waala 14
# Ack recieved for packet id 14
# 14 (65, 5)
# cback waala 15
# 0
# sent 2
# 10
# 2 11 21
# lala
# Ack recieved for packet id 15
# 15 (70, 5)
# cback waala 16
# Ack recieved for packet id 16
# 16 (75, 5)
# cback waala 17
# 0
# 10
# 2 12 21
# lala
# Ack recieved for packet id 17
# 17 (80, 5)
# cback waala 18
# Ack recieved for packet id 18
# 18 (85, 5)
# cback waala 19
# 0
# done 3
# 10
# 3 21 21
# lala
# Ack recieved for packet id 19
# 19 (90, 5)
# cback waala 20
# Ack recieved for packet id 20
# 20 (95, 5)
# cback waala 21
# 0
# sent 3
# 10
# 3 11 21
# lala
# Ack recieved for packet id 21
# 21 (100, 5)
# cback waala 22
# Ack recieved for packet id 22
# 22 (105, 5)
# cback waala 23
# 0
# 10
# 3 12 21
# lala
# Ack recieved for packet id 23
# 23 (110, 5)
# cback waala 24
# Ack recieved for packet id 24
# 24 (115, 5)
# cback waala 25
# 0
# done 4
# 10
# 4 21 21
# lala
# Ack recieved for packet id 25
# 25 (120, 5)
# cback waala 26
# Ack recieved for packet id 26
# 26 (125, 5)
# cback waala 27
# 0
# sent 4
# 10
# 4 11 21
# lala
# Ack recieved for packet id 27
# 27 (130, 5)
# cback waala 28
# Ack recieved for packet id 28
# 28 (135, 5)
# cback waala 29
# 0
# 10
# 4 12 21
# lala
# Ack recieved for packet id 29
# 29 (140, 5)
# cback waala 30
# Ack recieved for packet id 30
# 30 (145, 5)
# cback waala 31
# 0
# done 5
# 10
# 5 21 21
# lala
# Ack recieved for packet id 31
# 31 (150, 5)
# cback waala 32
# Ack recieved for packet id 32
# 32 (155, 5)
# cback waala 33
# 0
# sent 5
# 10
# 5 11 21
# lala
# Ack recieved for packet id 33
# 33 (160, 5)
# cback waala 34
# Ack recieved for packet id 34
# 34 (165, 5)
# cback waala 35
# 0
# 10
# 5 12 21
# lala
# Ack recieved for packet id 35
# 35 (170, 5)
# cback waala 36
# Ack recieved for packet id 36
# 36 (175, 5)
# cback waala 37
# 0
# done 6
# 10
# 6 21 21
# lala
# Ack recieved for packet id 37
# 37 (180, 5)
# cback waala 38
# Ack recieved for packet id 38
# 38 (185, 5)
# cback waala 39
# 0
# sent 6
# 10
# 6 11 21
# lala
# Ack recieved for packet id 39
# 39 (190, 5)
# cback waala 40
# Ack recieved for packet id 40
# 40 (195, 5)
# cback waala 41
# 0
# 10
# 6 12 21
# lala
# Ack recieved for packet id 41
# 41 (200, 5)
# cback waala 42
# Ack recieved for packet id 42
# 42 (205, 5)
# cback waala 43
# 0
# done 7
# 10
# 7 21 21
# lala
# Ack recieved for packet id 43
# 43 (210, 5)
# cback waala 44
# Ack recieved for packet id 44
# 44 (215, 5)
# cback waala 45
# 0
# sent 7
# 10
# 7 11 21
# lala
# Ack recieved for packet id 45
# 45 (220, 5)
# cback waala 46
# Ack recieved for packet id 46
# 46 (225, 5)
# cback waala 47
# 0
# 10
# 7 12 21
# lala
# Ack recieved for packet id 47
# 47 (230, 5)
# cback waala 48
# Ack recieved for packet id 48
# 48 (235, 5)
# cback waala 49
# 0
# done 8
# 10
# 8 21 21
# lala
# Ack recieved for packet id 49
# 49 (240, 5)
# cback waala 50
# Ack recieved for packet id 50
# 50 (245, 5)
# cback waala 51
# 0
# sent 8
# 10
# 8 11 21
# lala
# Ack recieved for packet id 51
# 51 (250, 5)
# cback waala 52
# Ack recieved for packet id 52
# 52 (255, 5)
# cback waala 53
# 0
# 10
# 8 12 21
# lala
# Ack recieved for packet id 53
# 53 (260, 5)
# cback waala 54
# Ack recieved for packet id 54
# 54 (265, 5)
# cback waala 55
# 0
# done 9
# 10
# 9 21 21
# lala
# Ack recieved for packet id 55
# 55 (270, 5)
# cback waala 56
# Ack recieved for packet id 56
# 56 (275, 5)
# cback waala 57
# 0
# sent 9
# fin called by21
# 10
# 9 11 21
# lala
# Ack recieved for packet id 57
# 57 (280, 5)
# cback waala 58
# Ack recieved for packet id 58
# 58 (285, 5)
# cback waala 59
# 0
# 10
# 9 12 21
# lala
# Ack recieved for packet id 59
# 59 (290, 5)
# cback waala 60
# Ack recieved for packet id 60
# 60 (295, 5)
# cback waala 61
# 0
# fin called by11
# fin called by12
# enter
# 300
# Exception in thread Thread-59:
# Traceback (most recent call last):
#   File "/home/vishal/.pyenv/versions/3.5.2/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/home/vishal/.pyenv/versions/3.5.2/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/vishal/.pyenv/versions/python-3.5.2/lib/python3.5/site-packages/rpyc/utils/helpers.py", line 210, in _bg_server
#     self._conn.serve(self.SERVE_INTERVAL)
#   File "/home/vishal/.pyenv/versions/python-3.5.2/lib/python3.5/site-packages/rpyc/core/protocol.py", line 387, in serve
#     data = self._channel.poll(timeout) and self._channel.recv()
#   File "/home/vishal/.pyenv/versions/python-3.5.2/lib/python3.5/site-packages/rpyc/core/channel.py", line 50, in recv
#     header = self.stream.read(self.FRAME_HEADER.size)
#   File "/home/vishal/.pyenv/versions/python-3.5.2/lib/python3.5/site-packages/rpyc/core/stream.py", line 230, in read
#     raise EOFError("connection closed by peer")
# EOFError: connection closed by peer

# %%
d = {}
d['abc'] = 1
d['cde'] = 2

# %%
for key,value in d.items():
    print(key, value)
# Out:
# cde 2
# abc 1

# %%
def f(kl):
    kl[0] = 1

# %%
l = [0,2,3]

# %%
f(l[0:1])

# %%
l
# Out:
# [0, 2, 3]

# %%
s = 3
if (s != 3):
    print(s)
